# %%
from parse_pubmed_xml import PubMedData

# %%
data = PubMedData.from_dir('../data')

# %%
data.pubinfo
# Out:
#          pub_date_year pub_date_month  \
# 26998820          2016             06
# 31362644          2019            Jul
# 31610401          2019            Nov
# 32300060          2020            Apr
# 32310197          2020            Apr
# 32335779          2020            Apr
#
#                                                journal_name
# 26998820                      European journal of neurology
# 31362644                           Nutritional neuroscience
# 31610401           Multiple sclerosis and related disorders
# 32300060                                          Neurology
# 32310197                                NeuroRehabilitation
# 32335779  Neurological sciences : official journal of th...

# %%
data.text
# Out:
#                                               article_title  \
# 26998820  Vitamin D, HLA-DRB1 and Epstein-Barr virus ant...
# 31362644  The role of nutritional factors during adolesc...
# 31610401  Randomized-controlled trial of a modified Medi...
# 32300060  Vitamin D, smoking, EBV, and long-term cogniti...
# 32310197  Effect of task-oriented circuit training on mo...
# 32335779  Effects of THC/CBD oromucosal spray on spastic...
#
#                                               abstract_text  \
# 26998820  BACKGROUND AND PURPOSE: Our objective was to s...
# 31362644  Objective: The potential role of nutritional f...
# 31610401  BACKGROUND: There is a high level of interest ...
# 32300060  OBJECTIVE: To investigate whether vitamin D, s...
# 32310197  BACKGROUND: Exercise training has positive eff...
# 32335779  INTRODUCTION: The approval of 9-δ-tetrahydocan...
#
#                                                    keywords
# ...

# %%
data.pubtype
# Out:
#                ui             publication_type
# 26998820  D016428              Journal Article
# 26998820  D016449  Randomized Controlled Trial
# 31362644  D016428              Journal Article
# 31610401  D016428              Journal Article
# 32300060  D016428              Journal Article
# 32310197  D016428              Journal Article
# 32335779  D016428              Journal Article

# %%
data.chems
# Out:
#                ui                            chemicals
# 26998820  C104450                  25-hydroxyvitamin D
# 26998820  C417029        EBV-encoded nuclear antigen 1
# 26998820  D014807                            Vitamin D
# 26998820  D019309  Epstein-Barr Virus Nuclear Antigens
# 26998820  D059811                      HLA-DRB1 Chains

# %%
data.mesh
# Out:
#                ui                        mesh_headings
# 26998820  D000293                           Adolescent
# 26998820  D000328                                Adult
# 26998820  D005260                               Female
# 26998820  D006801                               Humans
# 26998820  D008297                                 Male
# 26998820  D008875                          Middle Aged
# 26998820  D009103                   Multiple Sclerosis
# 26998820  D011446                  Prospective Studies
# 26998820  D014807                            Vitamin D
# 26998820  D019309  Epstein-Barr Virus Nuclear Antigens
# 26998820  D055815                          Young Adult
# 26998820  D059811                      HLA-DRB1 Chains
